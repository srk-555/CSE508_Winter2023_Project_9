# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r"C:\Users\shree\OneDrive\Desktop\IR Project Working Directory\product_reviews.xlsx")
df
# Out:
#         unique_id        asin  \
# 0      0785758968  0785758968
# 1      0452279550  0452279550
# 2      1599620065  1599620065
# 3      0743277724  0743277724
# 4      061318114X  061318114X
# ...           ...         ...
# 72674  B00006IUU0  B00006IUU0
# 72675  B00006IUU0  B00006IUU0
# 72676  B00006IUU0  B00006IUU0
# 72677  B00006IUU0  B00006IUU0
# 72678  B00006IUU0  B00006IUU0
#
#                                             product_name  \
# 0                        Sphere: Books: Michael Crichton
# 1      Healing from the Heart: A Leading Surgeon Comb...
# 2      Mythology: DC Comics Art of Alex Ross 2007 Cal...
# 3      Pegasus Descending: A Dave Robicheaux Novel (D...
# 4      Guns, Germs, and Steel: The Fates of Human Soc...
# ...                                                  ...
# 72674  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72675  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72676  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72677  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72678  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
#
#                product_type  rating  \
# 0                     books     5.0
# 1                     books     4.0
# 2                     books     5.0
# 3                     books     4.0
# 4                     books     5.0
# ...                     ...     ...
# 72674  kitchen & housewares     5.0
# 72675  kitchen & housewares     5.0
# 72676  kitchen & housewares     5.0
# 72677  kitchen & housewares     5.0
# 72678  kitchen & housewares     5.0
#
#                                             review_title  \
# 0                        One of the best Crichton novels
# 1                             The Medicine of the Future
# 2                                             Beautiful!
# 3                               For lovers of Robicheaux
# 4      Excellent and broad survey of the development ...
# ...                                                  ...
# 72674                                 It's cold outside!
# 72675                                        Great Gift!
# 72676  A must have for coffee and hot drink users all...
# 72677  Great little work horse that Makes more things...
# 72678                                           LOVE IT!
#
#                                              review_text initial_sentiment
# 0      Sphere by Michael Crichton is an excellant nov...          positive
# 1      Dr. Oz is an accomplished heart surgeon in the...          positive
# 2      The most gorgeous artwork in comic books. Cont...          positive
# 3      This book is for lovers of Robicheaux.  His de...          positive
# 4      This is going to be a short and sweet review b...          positive
# ...                                                  ...               ...
# 72674  What a perfect little machine! I love my CocoM...          positive
# 72675  I gave this as a gift and was told this makes ...          positive
# 72676  We got this as a Christmas gift in December an...          positive
# 72677  I got this little machine when it first came o...          positive
# 72678  My mom bought this for me for Christmas (well,...          positive
#
# [72679 rows x 8 columns]

# %%
df.nunique()
# Out:
# unique_id            13520
# asin                 13520
# product_name         13295
# product_type             5
# rating                   4
# review_title         58832
# review_text          65056
# initial_sentiment        2
# dtype: int64

# %%
#Removing duplicates if any
df = df.drop_duplicates().copy()
df = pd.DataFrame(df)
df.reset_index(inplace = True)
df.nunique()
# Out:
# index                72638
# unique_id            13520
# asin                 13520
# product_name         13295
# product_type             5
# rating                   4
# review_title         58832
# review_text          65056
# initial_sentiment        2
# dtype: int64

# %%
unique_products = df.groupby(by='unique_id')
unique_products.groups
# Out:
# {'0001047574': [432], '0001053116': [1885], '0006530702': [252], '0007153589': [1358], '0007172303': [1693], '0025671111': [797], '0027085201': [46], '0028624513': [681], '002900151X': [1528], '0029066824': [1298], '0029177766': [310], '0041330013': [626], '0060005726': [1282], '0060007443': [1821], '0060014016': [1065], '0060084383': [873], '0060088877': [753], '0060092572': [1255], '0060099682': [1333], '0060161620': [961], '006016848X': [1194], '0060170522': [1520], '0060172126': [1392], '0060174722': [752], '0060188782': [1968], '0060193611': [1634], '0060196823': [224], '0060264187': [58], '0060283149': [207], '0060392452': [1795], '0060392959': [723], '006039319X': [1990], '0060507152': [1453], '0060510358': [382], '0060514396': [133], '006051518x': [105], '006051812X': [1800], '0060523921': [1857], '0060525258': [362], '0060529709': [234], '0060530677': [442], '0060531134': [1843], '0060534230': [680], '0060544481': [1037], '0060545623': [1898], '0060554142': [1167], '0060562978': [1758], '0060562994': [1635], '0060563443': [1250], '0060582529': [1346], '0060583932': [312], '006058629X': [636], '0060586621': [670], '0060590270': [1529], '0060675365': [1873], '0060698632': [583], '006073132x': [800, 1061], '0060735651': [1076], '0060736682': [1079], '0060744499': [327], '0060746378': [95], '0060757345': [36], '0060760028': [1787], '0060764686': [1009], '0060765410': [1215], '0060797525': [1316], '0060799919': [386], '0060828412': [113], '0060832851': [1310], '0060840986': [1836], '0060849681': [1450], '0060897945': [93], '0060897988': [1554], '0060914289': [443], '0060920467': [1762], '0060922583': [1395], '0060924632': [315], '0060927267': [808], '0060927909': [977], '0060929421': [871], '0060933852': [1317], '0060936770': [824], '0060955228': [1593], '0060955481': [320], '0060955678': [982], '0060955988': [1020], '0060957174': [1644], '0060958219': [99], '0060969571': [709], '0060975903': [1434], '006098726X': [1241], '0061000043': [167], '0061012289': [1506], '0061074292': [44], '0061091561': [118], '0061098787': [230], '0061120006': [1340], '006112074X': [907], '0061129747': [593], '006113029X': [1530], ...}

# %%
df
# Out:
#        index   unique_id        asin  \
# 0          0  0785758968  0785758968
# 1          1  0452279550  0452279550
# 2          2  1599620065  1599620065
# 3          3  0743277724  0743277724
# 4          4  061318114X  061318114X
# ...      ...         ...         ...
# 72633  72674  B00006IUU0  B00006IUU0
# 72634  72675  B00006IUU0  B00006IUU0
# 72635  72676  B00006IUU0  B00006IUU0
# 72636  72677  B00006IUU0  B00006IUU0
# 72637  72678  B00006IUU0  B00006IUU0
#
#                                             product_name  \
# 0                        Sphere: Books: Michael Crichton
# 1      Healing from the Heart: A Leading Surgeon Comb...
# 2      Mythology: DC Comics Art of Alex Ross 2007 Cal...
# 3      Pegasus Descending: A Dave Robicheaux Novel (D...
# 4      Guns, Germs, and Steel: The Fates of Human Soc...
# ...                                                  ...
# 72633  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72634  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72635  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72636  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72637  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
#
#                product_type  rating  \
# 0                     books     5.0
# 1                     books     4.0
# 2                     books     5.0
# 3                     books     4.0
# 4                     books     5.0
# ...                     ...     ...
# 72633  kitchen & housewares     5.0
# 72634  kitchen & housewares     5.0
# 72635  kitchen & housewares     5.0
# 72636  kitchen & housewares     5.0
# 72637  kitchen & housewares     5.0
#
#                                             review_title  \
# 0                        One of the best Crichton novels
# 1                             The Medicine of the Future
# 2                                             Beautiful!
# 3                               For lovers of Robicheaux
# 4      Excellent and broad survey of the development ...
# ...                                                  ...
# 72633                                 It's cold outside!
# 72634                                        Great Gift!
# 72635  A must have for coffee and hot drink users all...
# 72636  Great little work horse that Makes more things...
# 72637                                           LOVE IT!
#
#                                              review_text initial_sentiment
# 0      Sphere by Michael Crichton is an excellant nov...          positive
# 1      Dr. Oz is an accomplished heart surgeon in the...          positive
# 2      The most gorgeous artwork in comic books. Cont...          positive
# 3      This book is for lovers of Robicheaux.  His de...          positive
# 4      This is going to be a short and sweet review b...          positive
# ...                                                  ...               ...
# 72633  What a perfect little machine! I love my CocoM...          positive
# 72634  I gave this as a gift and was told this makes ...          positive
# 72635  We got this as a Christmas gift in December an...          positive
# 72636  I got this little machine when it first came o...          positive
# 72637  My mom bought this for me for Christmas (well,...          positive
#
# [72638 rows x 9 columns]

# %%
# appending new column to dataframe for number of reviews for each product
frequencies = dict(df['unique_id'].value_counts())

temp_freq  = []
for uid in df['unique_id']:
    temp_freq.append(frequencies[uid])
df['review_frequency'] = temp_freq
df
# Out:
#        index   unique_id        asin  \
# 0          0  0785758968  0785758968
# 1          1  0452279550  0452279550
# 2          2  1599620065  1599620065
# 3          3  0743277724  0743277724
# 4          4  061318114X  061318114X
# ...      ...         ...         ...
# 72633  72674  B00006IUU0  B00006IUU0
# 72634  72675  B00006IUU0  B00006IUU0
# 72635  72676  B00006IUU0  B00006IUU0
# 72636  72677  B00006IUU0  B00006IUU0
# 72637  72678  B00006IUU0  B00006IUU0
#
#                                             product_name  \
# 0                        Sphere: Books: Michael Crichton
# 1      Healing from the Heart: A Leading Surgeon Comb...
# 2      Mythology: DC Comics Art of Alex Ross 2007 Cal...
# 3      Pegasus Descending: A Dave Robicheaux Novel (D...
# 4      Guns, Germs, and Steel: The Fates of Human Soc...
# ...                                                  ...
# 72633  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72634  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72635  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72636  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
# 72637  Mr. Coffee Cocomotion Hot Chocolate Maker: Kit...
#
#                product_type  rating  \
# 0                     books     5.0
# 1                     books     4.0
# 2                     books     5.0
# 3                     books     4.0
# 4                     books     5.0
# ...                     ...     ...
# 72633  kitchen & housewares     5.0
# 72634  kitchen & housewares     5.0
# 72635  kitchen & housewares     5.0
# 72636  kitchen & housewares     5.0
# 72637  kitchen & housewares     5.0
#
#                                             review_title  \
# 0                        One of the best Crichton novels
# 1                             The Medicine of the Future
# 2                                             Beautiful!
# 3                               For lovers of Robicheaux
# 4      Excellent and broad survey of the development ...
# ...                                                  ...
# 72633                                 It's cold outside!
# 72634                                        Great Gift!
# 72635  A must have for coffee and hot drink users all...
# 72636  Great little work horse that Makes more things...
# 72637                                           LOVE IT!
#
#                                              review_text initial_sentiment  \
# 0      Sphere by Michael Crichton is an excellant nov...          positive
# 1      Dr. Oz is an accomplished heart surgeon in the...          positive
# 2      The most gorgeous artwork in comic books. Cont...          positive
# 3      This book is for lovers of Robicheaux.  His de...          positive
# 4      This is going to be a short and sweet review b...          positive
# ...                                                  ...               ...
# 72633  What a perfect little machine! I love my CocoM...          positive
# 72634  I gave this as a gift and was told this makes ...          positive
# 72635  We got this as a Christmas gift in December an...          positive
# 72636  I got this little machine when it first came o...          positive
# 72637  My mom bought this for me for Christmas (well,...          positive
#
#        review_frequency
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     2
# ...                 ...
# 72633                 7
# 72634                 7
# 72635                 7
# 72636                 7
# 72637                 7
#
# [72638 rows x 10 columns]

# %% [markdown]
# ##### Printing all product types

# %%
all_product_types_with_freqs = dict(df['product_type'].value_counts())
all_product_types = list(all_product_types_with_freqs.keys())
all_product_types
# Out:
# ['dvd',
#  'kitchen & housewares',
#  'electronics',
#  'books',
#  'computer & video games']

# %% [markdown]
# ### Cleaning the review_text column
# Lower case each review<br>
# Remove stopwords<br>
# Remove punctuations and extra symbols<br>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72638 entries, 0 to 72637
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              72638 non-null  int64
#  1   unique_id          72638 non-null  object
#  2   asin               72638 non-null  object
#  3   product_name       72638 non-null  object
#  4   product_type       72638 non-null  object
#  5   rating             72638 non-null  float64
#  6   review_title       72638 non-null  object
#  7   review_text        72638 non-null  object
#  8   initial_sentiment  72638 non-null  object
#  9   review_frequency   72638 non-null  int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 5.5+ MB

# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\shree\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\shree\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\shree\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in c:\users\shree\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\shree\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: colorama in c:\users\shree\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('all')
from nltk.corpus import stopwords

# get english stopwords from nltk.corpus.stopwords 
stopwords_eng = stopwords.words('english')
stopwords_eng
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping grammars\basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping models\bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping grammars\book_grammars.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]    |   Unzipping corpora\europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\shree\anaconda3\nltk_data...

# %%
from nltk.corpus import stopwords

# get english stopwords from nltk.corpus.stopwords 
stopwords_eng = stopwords.words('english')
stopwords_eng
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# Iterate through each row to remove stoprwords, punctuations, lowercase the text
import re
i = 0
for index, row in df.iterrows():
    review_text = str(row['review_text']).strip().lower()      
    review_tokens = review_text.split()
    
    result = []
    for token in review_tokens:
        if token not in stopwords_eng:
            result.append(re.sub(r'[^\w\s]','', token))
    df.at[index,'review_text'] = ' '.join(result)  
    df.at[index,'product_name'] = str(row['product_name']).strip().lower()
    df.at[index,'review_title'] = str(row['review_title']).strip().lower()
df
# Out:
#        index   unique_id        asin  \
# 0          0  0785758968  0785758968
# 1          1  0452279550  0452279550
# 2          2  1599620065  1599620065
# 3          3  0743277724  0743277724
# 4          4  061318114X  061318114X
# ...      ...         ...         ...
# 72633  72674  B00006IUU0  B00006IUU0
# 72634  72675  B00006IUU0  B00006IUU0
# 72635  72676  B00006IUU0  B00006IUU0
# 72636  72677  B00006IUU0  B00006IUU0
# 72637  72678  B00006IUU0  B00006IUU0
#
#                                             product_name  \
# 0                        sphere: books: michael crichton
# 1      healing from the heart: a leading surgeon comb...
# 2      mythology: dc comics art of alex ross 2007 cal...
# 3      pegasus descending: a dave robicheaux novel (d...
# 4      guns, germs, and steel: the fates of human soc...
# ...                                                  ...
# 72633  mr. coffee cocomotion hot chocolate maker: kit...
# 72634  mr. coffee cocomotion hot chocolate maker: kit...
# 72635  mr. coffee cocomotion hot chocolate maker: kit...
# 72636  mr. coffee cocomotion hot chocolate maker: kit...
# 72637  mr. coffee cocomotion hot chocolate maker: kit...
#
#                product_type  rating  \
# 0                     books     5.0
# 1                     books     4.0
# 2                     books     5.0
# 3                     books     4.0
# 4                     books     5.0
# ...                     ...     ...
# 72633  kitchen & housewares     5.0
# 72634  kitchen & housewares     5.0
# 72635  kitchen & housewares     5.0
# 72636  kitchen & housewares     5.0
# 72637  kitchen & housewares     5.0
#
#                                             review_title  \
# 0                        one of the best crichton novels
# 1                             the medicine of the future
# 2                                             beautiful!
# 3                               for lovers of robicheaux
# 4      excellent and broad survey of the development ...
# ...                                                  ...
# 72633                                 it's cold outside!
# 72634                                        great gift!
# 72635  a must have for coffee and hot drink users all...
# 72636  great little work horse that makes more things...
# 72637                                           love it!
#
#                                              review_text initial_sentiment  \
# 0      sphere michael crichton excellant novel certai...          positive
# 1      dr oz accomplished heart surgeon field cardiac...          positive
# 2      gorgeous artwork comic books contains extraord...          positive
# 3      book lovers robicheaux demons seem put rest re...          positive
# 4      going short sweet review many others commented...          positive
# ...                                                  ...               ...
# 72633  perfect little machine love cocomotion perfect...          positive
# 72634       gave gift told makes great cup hot chocolate          positive
# 72635  got christmas gift december used lot past coup...          positive
# 72636  got little machine first came market fan presw...          positive
# 72637  mom bought christmas well name tag im positive...          positive
#
#        review_frequency
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     2
# ...                 ...
# 72633                 7
# 72634                 7
# 72635                 7
# 72636                 7
# 72637                 7
#
# [72638 rows x 10 columns]

# %%
new_df = df[['product_name', 'review_text', 'rating', 'initial_sentiment']]
new_df
# Out:
#                                             product_name  \
# 0                        sphere: books: michael crichton
# 1      healing from the heart: a leading surgeon comb...
# 2      mythology: dc comics art of alex ross 2007 cal...
# 3      pegasus descending: a dave robicheaux novel (d...
# 4      guns, germs, and steel: the fates of human soc...
# ...                                                  ...
# 72633  mr. coffee cocomotion hot chocolate maker: kit...
# 72634  mr. coffee cocomotion hot chocolate maker: kit...
# 72635  mr. coffee cocomotion hot chocolate maker: kit...
# 72636  mr. coffee cocomotion hot chocolate maker: kit...
# 72637  mr. coffee cocomotion hot chocolate maker: kit...
#
#                                              review_text  rating  \
# 0      sphere michael crichton excellant novel certai...     5.0
# 1      dr oz accomplished heart surgeon field cardiac...     4.0
# 2      gorgeous artwork comic books contains extraord...     5.0
# 3      book lovers robicheaux demons seem put rest re...     4.0
# 4      going short sweet review many others commented...     5.0
# ...                                                  ...     ...
# 72633  perfect little machine love cocomotion perfect...     5.0
# 72634       gave gift told makes great cup hot chocolate     5.0
# 72635  got christmas gift december used lot past coup...     5.0
# 72636  got little machine first came market fan presw...     5.0
# 72637  mom bought christmas well name tag im positive...     5.0
#
#       initial_sentiment
# 0              positive
# 1              positive
# 2              positive
# 3              positive
# 4              positive
# ...                 ...
# 72633          positive
# 72634          positive
# 72635          positive
# 72636          positive
# 72637          positive
#
# [72638 rows x 4 columns]

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

new_df['normal_sentiment_score'] = ''
for index, row in new_df.iterrows():    
    # Create a SentimentIntensityAnalyzer object
    analyzer = SentimentIntensityAnalyzer()
    # Use the analyzer to get a sentiment score for the text
    scores = analyzer.polarity_scores(row['review_text'])
    new_df.at[index,'normal_sentiment_score'] = scores['compound']

new_df
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                             product_name  \
# 0                        sphere: books: michael crichton
# 1      healing from the heart: a leading surgeon comb...
# 2      mythology: dc comics art of alex ross 2007 cal...
# 3      pegasus descending: a dave robicheaux novel (d...
# 4      guns, germs, and steel: the fates of human soc...
# ...                                                  ...
# 72633  mr. coffee cocomotion hot chocolate maker: kit...
# 72634  mr. coffee cocomotion hot chocolate maker: kit...
# 72635  mr. coffee cocomotion hot chocolate maker: kit...
# 72636  mr. coffee cocomotion hot chocolate maker: kit...
# 72637  mr. coffee cocomotion hot chocolate maker: kit...
#
#                                              review_text  rating  \
# 0      sphere michael crichton excellant novel certai...     5.0
# 1      dr oz accomplished heart surgeon field cardiac...     4.0
# 2      gorgeous artwork comic books contains extraord...     5.0
# 3      book lovers robicheaux demons seem put rest re...     4.0
# 4      going short sweet review many others commented...     5.0
# ...                                                  ...     ...
# 72633  perfect little machine love cocomotion perfect...     5.0
# 72634       gave gift told makes great cup hot chocolate     5.0
# 72635  got christmas gift december used lot past coup...     5.0
# 72636  got little machine first came market fan presw...     5.0
# 72637  mom bought christmas well name tag im positive...     5.0
#
#       initial_sentiment normal_sentiment_score
# 0              positive                 0.9231
# 1              positive                   0.93
# 2              positive                 0.9118
# 3              positive                -0.8442
# 4              positive                 0.9912
# ...                 ...                    ...
# 72633          positive                 0.9745
# 72634          positive                 0.7906
# 72635          positive                -0.1531
# 72636          positive                 0.9719
# 72637          positive                 0.9899
#
# [72638 rows x 5 columns]

# %%
# Cslculating sentiment by 'normal_sentiment_score', -1 being most negative 0 being neutral and 1 being most positive

new_df['normal_sentiment'] = ''
new_df['rating_by_normal_sentiment'] = ''
for index, row in new_df.iterrows():
  if row['normal_sentiment_score'] < 0.0:
    if row['normal_sentiment_score'] <= -0.6:
      new_df.at[index,'normal_sentiment'] = 'negative'
      new_df.at[index,'rating_by_normal_sentiment'] = 1
    else:
      new_df.at[index,'normal_sentiment'] = 'negative'
      new_df.at[index,'rating_by_normal_sentiment'] = 2
  elif row['normal_sentiment_score'] == 0.0:
    new_df.at[index,'normal_sentiment'] = 'neutral'
    new_df.at[index,'rating_by_normal_sentiment'] = 3
  else:
    if row['normal_sentiment_score'] <= 0.5:
      new_df.at[index,'normal_sentiment'] = 'positive'
      new_df.at[index,'rating_by_normal_sentiment'] = 4
    else:
      new_df.at[index,'normal_sentiment'] = 'positive'
      new_df.at[index,'rating_by_normal_sentiment'] = 5
new_df
# Out:
#                                             product_name  \
# 0                        sphere: books: michael crichton
# 1      healing from the heart: a leading surgeon comb...
# 2      mythology: dc comics art of alex ross 2007 cal...
# 3      pegasus descending: a dave robicheaux novel (d...
# 4      guns, germs, and steel: the fates of human soc...
# ...                                                  ...
# 72633  mr. coffee cocomotion hot chocolate maker: kit...
# 72634  mr. coffee cocomotion hot chocolate maker: kit...
# 72635  mr. coffee cocomotion hot chocolate maker: kit...
# 72636  mr. coffee cocomotion hot chocolate maker: kit...
# 72637  mr. coffee cocomotion hot chocolate maker: kit...
#
#                                              review_text  rating  \
# 0      sphere michael crichton excellant novel certai...     5.0
# 1      dr oz accomplished heart surgeon field cardiac...     4.0
# 2      gorgeous artwork comic books contains extraord...     5.0
# 3      book lovers robicheaux demons seem put rest re...     4.0
# 4      going short sweet review many others commented...     5.0
# ...                                                  ...     ...
# 72633  perfect little machine love cocomotion perfect...     5.0
# 72634       gave gift told makes great cup hot chocolate     5.0
# 72635  got christmas gift december used lot past coup...     5.0
# 72636  got little machine first came market fan presw...     5.0
# 72637  mom bought christmas well name tag im positive...     5.0
#
#       initial_sentiment normal_sentiment_score normal_sentiment  \
# 0              positive                 0.9231         positive
# 1              positive                   0.93         positive
# 2              positive                 0.9118         positive
# 3              positive                -0.8442         negative
# 4              positive                 0.9912         positive
# ...                 ...                    ...              ...
# 72633          positive                 0.9745         positive
# 72634          positive                 0.7906         positive
# 72635          positive                -0.1531         negative
# 72636          positive                 0.9719         positive
# 72637          positive                 0.9899         positive
#
#       rating_by_normal_sentiment
# 0                              5
# 1                              5
# 2                              5
# 3                              1
# 4                              5
# ...                          ...
# 72633                          5
# 72634                          5
# 72635                          2
# 72636                          5
# 72637                          5
#
# [72638 rows x 7 columns]

# %%
# Excluding outliers or contradicting rating-review pairs example - where rating is excellent but review subitted is negative
for index, row in new_df.iterrows():
    if abs(int(row['rating_by_normal_sentiment'])-int(row['rating']))>=3:
        new_df.drop(index, inplace=True)
new_df
# Out:
#                                             product_name  \
# 0                        sphere: books: michael crichton
# 1      healing from the heart: a leading surgeon comb...
# 2      mythology: dc comics art of alex ross 2007 cal...
# 4      guns, germs, and steel: the fates of human soc...
# 5      world's fairs and the end of progress: an insi...
# ...                                                  ...
# 72632  mr. coffee cocomotion hot chocolate maker: kit...
# 72633  mr. coffee cocomotion hot chocolate maker: kit...
# 72634  mr. coffee cocomotion hot chocolate maker: kit...
# 72636  mr. coffee cocomotion hot chocolate maker: kit...
# 72637  mr. coffee cocomotion hot chocolate maker: kit...
#
#                                              review_text  rating  \
# 0      sphere michael crichton excellant novel certai...     5.0
# 1      dr oz accomplished heart surgeon field cardiac...     4.0
# 2      gorgeous artwork comic books contains extraord...     5.0
# 4      going short sweet review many others commented...     5.0
# 5      since worlds fair fanatic read almost everythi...     4.0
# ...                                                  ...     ...
# 72632  four children plus lots friends make hot choco...     5.0
# 72633  perfect little machine love cocomotion perfect...     5.0
# 72634       gave gift told makes great cup hot chocolate     5.0
# 72636  got little machine first came market fan presw...     5.0
# 72637  mom bought christmas well name tag im positive...     5.0
#
#       initial_sentiment normal_sentiment_score normal_sentiment  \
# 0              positive                 0.9231         positive
# 1              positive                   0.93         positive
# 2              positive                 0.9118         positive
# 4              positive                 0.9912         positive
# 5              positive                 0.9633         positive
# ...                 ...                    ...              ...
# 72632          positive                 0.9246         positive
# 72633          positive                 0.9745         positive
# 72634          positive                 0.7906         positive
# 72636          positive                 0.9719         positive
# 72637          positive                 0.9899         positive
#
#       rating_by_normal_sentiment
# 0                              5
# 1                              5
# 2                              5
# 4                              5
# 5                              5
# ...                          ...
# 72632                          5
# 72633                          5
# 72634                          5
# 72636                          5
# 72637                          5
#
# [60989 rows x 7 columns]

# %%
new_df.reset_index(inplace = True)
new_df
# Out:
#        index                                       product_name  \
# 0          0                    sphere: books: michael crichton
# 1          1  healing from the heart: a leading surgeon comb...
# 2          2  mythology: dc comics art of alex ross 2007 cal...
# 3          4  guns, germs, and steel: the fates of human soc...
# 4          5  world's fairs and the end of progress: an insi...
# ...      ...                                                ...
# 60984  72632  mr. coffee cocomotion hot chocolate maker: kit...
# 60985  72633  mr. coffee cocomotion hot chocolate maker: kit...
# 60986  72634  mr. coffee cocomotion hot chocolate maker: kit...
# 60987  72636  mr. coffee cocomotion hot chocolate maker: kit...
# 60988  72637  mr. coffee cocomotion hot chocolate maker: kit...
#
#                                              review_text  rating  \
# 0      sphere michael crichton excellant novel certai...     5.0
# 1      dr oz accomplished heart surgeon field cardiac...     4.0
# 2      gorgeous artwork comic books contains extraord...     5.0
# 3      going short sweet review many others commented...     5.0
# 4      since worlds fair fanatic read almost everythi...     4.0
# ...                                                  ...     ...
# 60984  four children plus lots friends make hot choco...     5.0
# 60985  perfect little machine love cocomotion perfect...     5.0
# 60986       gave gift told makes great cup hot chocolate     5.0
# 60987  got little machine first came market fan presw...     5.0
# 60988  mom bought christmas well name tag im positive...     5.0
#
#       initial_sentiment normal_sentiment_score normal_sentiment  \
# 0              positive                 0.9231         positive
# 1              positive                   0.93         positive
# 2              positive                 0.9118         positive
# 3              positive                 0.9912         positive
# 4              positive                 0.9633         positive
# ...                 ...                    ...              ...
# 60984          positive                 0.9246         positive
# 60985          positive                 0.9745         positive
# 60986          positive                 0.7906         positive
# 60987          positive                 0.9719         positive
# 60988          positive                 0.9899         positive
#
#       rating_by_normal_sentiment
# 0                              5
# 1                              5
# 2                              5
# 3                              5
# 4                              5
# ...                          ...
# 60984                          5
# 60985                          5
# 60986                          5
# 60987                          5
# 60988                          5
#
# [60989 rows x 8 columns]

# %%
# Accuracy of initial sentiment calculated by rating given Vs compound sentiment score calculated by SentimentIntensityAnalyzer()
from sklearn.metrics import accuracy_score
print("Calculated Sentment Accuracy ",accuracy_score(new_df['initial_sentiment'], new_df['normal_sentiment']))
# Out:
# Calculated Sentment Accuracy  0.9538113430290708

# %%
# Saving the intermediate dataframe for further reference
new_df.to_excel(r"C:\Users\shree\OneDrive\Desktop\IIITD Sem 2\I R\new_df_midReview.xlsx")

# %%
# Calculating accuracy for our rating 
from sklearn.metrics import confusion_matrix, classification_report

# Define the true labels and predicted labels
user_rating = list(new_df['rating'])
our_rating = list(new_df['rating_by_normal_sentiment'])
true_labels = user_rating
predicted_labels = our_rating

# Generate the confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Generate the classification report
cr = classification_report(true_labels, predicted_labels)

# Print the confusion matrix and classification report
# Plotting heatmap
import seaborn as sns
fig, ax = plt.subplots(figsize=(15,8)) 
sns.heatmap(cm_normal, annot=True, ax=ax)
ax.set_title('Heatmap for Caculated Rating Vs Original Rating', fontdict = {'fontsize' : 20})
plt.show()

print("\nClassification report:\n", cr)
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#          1.0       0.72      0.46      0.57      3933
#          2.0       0.20      0.29      0.24      2370
#          3.0       0.00      0.00      0.00         0
#          4.0       0.26      0.09      0.14     15588
#          5.0       0.73      0.91      0.81     39098
#
#     accuracy                           0.65     60989
#    macro avg       0.38      0.35      0.35     60989
# weighted avg       0.59      0.65      0.60     60989

# %%
! pip install ruamel-yaml
# Out:
# Requirement already satisfied: ruamel-yaml in c:\users\shree\anaconda3\lib\site-packages (0.17.21)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in c:\users\shree\anaconda3\lib\site-packages (from ruamel-yaml) (0.2.7)

# %%
! pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\shree\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: jinja2 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (8.1.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (0.7.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (1.10.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: setuptools in c:\users\shree\anaconda3\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\shree\anaconda3\lib\site-packages (from spacy) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\shree\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\shree\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\shree\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shree\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shree\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shree\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\shree\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\shree\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: colorama in c:\users\shree\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\shree\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\shree\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)

# %%
import nltk
from nltk.tokenize import word_tokenize
import spacy
import nltk
from nltk.corpus import wordnet
import spacy
nlp = spacy.load("en_core_web_sm")
! pip install afinn
nltk.download('wordnet')
negations = ["n't",'not', 'no', 'never', 'none', 'neither', 'nor', 'nowhere', 'hardly', 'scarcely', 'barely', 'doesn\'t', 'isn\'t', 'wasn\'t', 'shouldn\'t', 'wouldn\'t', 'couldn\'t', 'can\'t', 'won\'t', 'don\'t', 'didn\'t']

###### REMOVE PRONOUNS
# Define a function to remove relative pronouns from a sentence
def remove_relative_pronouns(text):
    # Tokenize the text
    tokens = word_tokenize(text)
    # Tag the tokens with their part of speech
    pos_tags = nltk.pos_tag(tokens)
    # Use regular expressions to identify and remove relative pronouns
    pattern = "^(that|which|who|whom|whose)$"
    filtered_tokens = [token for (token, pos) in pos_tags if not re.match(pattern, token, re.IGNORECASE)]
    # Join the filtered tokens back into a string
    filtered_text = " ".join(filtered_tokens)
    return filtered_text

# Example usage
# text = "The battery life of the phone is excellent but the camera quality is not that good."
text = "The battery life of the phone is good but the camera quality is not that good."
# text = "the quality of battery is poor"
filtered_text = remove_relative_pronouns(text)
print("\nOriginal Text : ", text)
print("\n\nAfter Removing Pronouns : ", filtered_text)

##### REMOVE ADVERBS KEEPING Negations
# Tokenize the sentence into individual words
tokens = nltk.word_tokenize(filtered_text)

# Use NLTK's part-of-speech tagging functionality to tag each word with its part of speech
pos_tags = nltk.pos_tag(tokens)
# Filter out any words that are tagged as adverbs (RB)
filtered_tokens = [token for token, pos in pos_tags if pos != 'RB' or token in negations]
# Join the remaining words back together into a single string
filtered_sentence = ' '.join(filtered_tokens)
# Print the filtered sentence
print("After Removing Adverbs(but keeping negations) : ", filtered_sentence)

##### JOIN RELATED NOUNS
skip = False
result = []

temp_tokens = list(nlp(filtered_sentence))
for i in range(len(temp_tokens)):
  if skip==True:
    skip = False
    continue  
  if nlp(str(temp_tokens[i]))[0].pos_ == "NOUN":
    if i == len(temp_tokens)-1:
        break
    if nlp(str(temp_tokens[i+1]))[0].pos_ == "NOUN":
      result.append(str(temp_tokens[i])+'_'+str(temp_tokens[i+1]))
      skip=True
    else:
      result.append(temp_tokens[i])
  else:
    result.append(temp_tokens[i])

for i in range(len(result)):
  result[i] = str(result[i])
  
resulting_text = ' '.join(result)
print("After Joining Related Words : ", resulting_text)

# Recording positions of negations 
pos_tokens = word_tokenize(resulting_text)
probable_negation_positions = []
original_resulting_text_tokens = pos_tokens.copy()
for i in range(len(pos_tokens)):
  if str(pos_tokens[i]) in negations:
    probable_negation_positions.append(i)
    probable_negation_positions.append(i+1)
    probable_negation_positions.append(i+2)

##### REPLACE NEGATED WORD BY THEIR ANTONYMS
import nltk
from nltk.sentiment.util import mark_negation
nlp = spacy.load("en_core_web_sm")

text = resulting_text.strip().lower()
text_tokens = text.split()
result = []

# Remove stopwords and punctuations
for token in text_tokens:
  if token not in stopwords_eng or token in negations:
    result.append(re.sub(r'[^\w\s]','',token))
clean_result = []
for item in result:
  if item != '':
    clean_result.append(item)

final = []
for item in clean_result:
  if nlp(item)[0].pos_ != "NOUN" or item in negations:
    final.append(item)
result_text = ' '.join(final)
# print("result Text is - ", result_text)

# Tokenize the text into words
words = nltk.word_tokenize(result_text)
# Mark the negations in the text
negation_marked_words = mark_negation(words)
# Extract the negated words
negations_NEG=[]
for item in negations:
  negations_NEG.append(item+'_NEG')
negated_words = [word for word in negation_marked_words if "_NEG" in word and word not in negations_NEG]

negated_word_original = []
for item in negated_words:
  negated_word_original.append(item[:-4])
print("Negated words in the text are : ", negated_word_original)

# Replacing negated words with their antonyms
# Define a function to get antonyms of a word using WordNet
# get the closest antonym of a word using WordNet
def get_closest_antonym(word):
    antonyms = []
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                antonyms.append(antonym.name())
    if not antonyms:
        return None
    
    word_synsets = wordnet.synsets(word)
    max_similarity = -1
    closest_antonym = None
    for antonym in antonyms:
        antonym_synsets = wordnet.synsets(antonym)
        for word_synset in word_synsets:
            for antonym_synset in antonym_synsets:
                similarity = word_synset.wup_similarity(antonym_synset)
                if similarity is not None and similarity > max_similarity:
                    max_similarity = similarity
                    closest_antonym = antonym
    return closest_antonym
toks = list(word_tokenize(resulting_text))

for i in range(len(toks)):
  if toks[i] in negated_word_original:
    if i in probable_negation_positions:
      toks[i] = get_closest_antonym(toks[i])
for i in range(len(toks)):
  toks[i] = str(toks[i])     
antonym_text = ' '.join(toks)
# aspect_resulting_input = []
# for i in range(len(toks)):
#   if toks[i] not in negations:
#     aspect_resulting_input.append(toks[i])

# for i in range(len(aspect_resulting_input)):
  

# # Example usage
# sentence = "it was not friendly"
# antonyms = get_antonyms_for_negated_words(sentence)
# print(antonyms)


##### EXTRACT ASPECTS AND THEIR DESCRIPTION
nlp = spacy.load("en_core_web_sm")
# doc = nlp(resulting_text)
doc = nlp(antonym_text)
# Extract aspects and associated adjectives
aspects = []
adjectives = []
aspect_adj_set = dict()
for token in doc:
    if token.pos_ == "NOUN":
        for child in token.children:
            if child.dep_ == "amod":
                aspects.append(token.text)
                adjectives.append(child.text)
                aspect_adj_set[token.text] = child.text
    elif token.pos_ == "ADJ":
        for child in token.head.children:
            if child.dep_ == "nsubj":
                aspects.append(child.text)
                adjectives.append(token.text)
                aspect_adj_set[child.text] = token.text
# Print results
print("\n\nAspects:", aspects)
print("Adjectives:", adjectives)
print("Aspects With Description:", aspect_adj_set)


import afinn
# initialize the AFINN lexicon
afn = afinn.Afinn()

aspect_sentiment_scores = dict()
for aspect in aspect_adj_set:
  aspect_sentiment_scores[aspect] = afn.score(aspect_adj_set[aspect].lower())
print("Aspects With Sentiment Scores (-5 to +5): ", aspect_sentiment_scores)

aspect_ratings = dict()
for aspect in aspect_sentiment_scores:
  if aspect_sentiment_scores[aspect]<0.0:
    if aspect_sentiment_scores[aspect]<=-4.0:
      aspect_ratings[aspect] = 1
    else:
      aspect_ratings[aspect] = 2
  elif aspect_sentiment_scores[aspect]==0.0:
    aspect_ratings[aspect] = 3
  else:
    if aspect_sentiment_scores[aspect]<=3.0:
      aspect_ratings[aspect] = 4
    else:
      aspect_ratings[aspect] = 5

print("Aspects With Ratings (Out of 5): ", aspect_ratings)
print('\n')



from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# Use the analyzer to get a sentiment score for the text
scores = analyzer.polarity_scores(text)

print("Normal Sentiment Score ", scores['compound'])
normal_sentiment_score = scores['compound']
rating_by_normal_sentiment = 0

if normal_sentiment_score <0.0:
  if normal_sentiment_score <=-0.6:
    rating_by_normal_sentiment = 1
  else:
    rating_by_normal_sentiment = 2
elif normal_sentiment_score == 0.0:
  rating_by_normal_sentiment = 3
else:
  if normal_sentiment_score <= 0.5:
    rating_by_normal_sentiment = 4
  else:
    rating_by_normal_sentiment = 5

print("Rating by Normal Sentiment Score: ", rating_by_normal_sentiment)

print("Sentient Score by Aspects: ", sum(aspect_sentiment_scores.values())/len(aspect_sentiment_scores.values()))

print("Rating by Aspect Sentiment Score: ", sum(aspect_ratings.values())/len(aspect_ratings.values()))
# Out:
# Requirement already satisfied: afinn in c:\users\shree\anaconda3\lib\site-packages (0.1)
#
# Original Text :  The battery life of the phone is good but the camera quality is not that good.
#
#
# After Removing Pronouns :  The battery life of the phone is good but the camera quality is not good .
# After Removing Adverbs(but keeping negations) :  The battery life of the phone is good but the camera quality is not good .
# After Joining Related Words :  The battery_life of the phone is good but the camera_quality is not good .
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Negated words in the text are :  ['good']
#
#
# Aspects: ['battery_life', 'camera_quality']
# Adjectives: ['good', 'bad']
# Aspects With Description: {'battery_life': 'good', 'camera_quality': 'bad'}
# Aspects With Sentiment Scores (-5 to +5):  {'battery_life': 3.0, 'camera_quality': -3.0}
# Aspects With Ratings (Out of 5):  {'battery_life': 4, 'camera_quality': 2}
#
#
# Normal Sentiment Score  0.7003
# Rating by Normal Sentiment Score:  5
# Sentient Score by Aspects:  0.0
# Rating by Aspect Sentiment Score:  3.0

# %%
nltk.data.path
# Out:
# ['C:\\Users\\shree/nltk_data',
#  'C:\\Users\\shree\\anaconda3\\nltk_data',
#  'C:\\Users\\shree\\anaconda3\\share\\nltk_data',
#  'C:\\Users\\shree\\anaconda3\\lib\\nltk_data',
#  'C:\\Users\\shree\\AppData\\Roaming\\nltk_data',
#  'C:\\nltk_data',
#  'D:\\nltk_data',
#  'E:\\nltk_data',
#  'C:/nltk_data/']

# %%
import nltk
from nltk.tokenize import word_tokenize
import spacy
import nltk
from nltk.corpus import wordnet
! pip install afinn
nltk.download('wordnet')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
negations = ["n't",'not', 'no', 'never', 'none', 'neither', 'nor', 'nowhere', 'hardly', 'scarcely', 'barely', 'doesn\'t', 'isn\'t', 'wasn\'t', 'shouldn\'t', 'wouldn\'t', 'couldn\'t', 'can\'t', 'won\'t', 'don\'t', 'didn\'t']

###### REMOVE PRONOUNS
# Define a function to remove relative pronouns from a sentence
def remove_relative_pronouns(text):
    # Tokenize the text
    tokens = word_tokenize(text)
    # Tag the tokens with their part of speech
    pos_tags = nltk.pos_tag(tokens)
    # Use regular expressions to identify and remove relative pronouns
    pattern = "^(that|which|who|whom|whose)$"
    filtered_tokens = [token for (token, pos) in pos_tags if not re.match(pattern, token, re.IGNORECASE)]
    # Join the filtered tokens back into a string
    filtered_text = " ".join(filtered_tokens)
    return filtered_text


def get_closest_antonym(word):
    antonyms = []
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            for antonym in lemma.antonyms():
                antonyms.append(antonym.name())
    if not antonyms:
        return None
    
    word_synsets = wordnet.synsets(word)
    max_similarity = -1
    closest_antonym = None
    for antonym in antonyms:
        antonym_synsets = wordnet.synsets(antonym)
        for word_synset in word_synsets:
            for antonym_synset in antonym_synsets:
                similarity = word_synset.wup_similarity(antonym_synset)
                if similarity is not None and similarity > max_similarity:
                    max_similarity = similarity
                    closest_antonym = antonym
    return closest_antonym
# Example usage
# text = "The battery life of the phone is excellent but the camera quality is not that good."
def retrieve_aspects_and_sentiments(text):
  # text = "The battery life of the phone is good but the camera quality is not that good."
  # text = "the quality of battery is poor"
  filtered_text = remove_relative_pronouns(text)
  # print("\nOriginal Text : ", text)
  # print("\n\nAfter Removing Pronouns : ", filtered_text)





  ##### REMOVE ADVERBS KEEPING Negations
  # Tokenize the sentence into individual words
  import nltk
  from nltk.tokenize import word_tokenize
  tokens = nltk.word_tokenize(filtered_text)

  # Use NLTK's part-of-speech tagging functionality to tag each word with its part of speech
  pos_tags = nltk.pos_tag(tokens)
  # Filter out any words that are tagged as adverbs (RB)
  filtered_tokens = [token for token, pos in pos_tags if pos != 'RB' or token in negations]
  # Join the remaining words back together into a single string
  filtered_sentence = ' '.join(filtered_tokens)
  # Print the filtered sentence
  # print("After Removing Adverbs(but keeping negations) : ", filtered_sentence)




  ##### JOIN RELATED NOUNS
  skip = False
  result = []
  import spacy
  nlp = spacy.load("en_core_web_sm")
  temp_tokens = list(nlp(filtered_sentence))
  for i in range(len(temp_tokens)):
    if skip==True:
      skip = False
      continue  
    if nlp(str(temp_tokens[i]))[0].pos_ == "NOUN":
      if i == len(temp_tokens)-1:
        break
      if nlp(str(temp_tokens[i+1]))[0].pos_ == "NOUN":
        result.append(str(temp_tokens[i])+'_'+str(temp_tokens[i+1]))
        skip=True
      else:
        result.append(temp_tokens[i])
    else:
      result.append(temp_tokens[i])

  for i in range(len(result)):
    result[i] = str(result[i])
    
  resulting_text = ' '.join(result)
  # print("After Joining Related Words : ", resulting_text)

  # Recording positions of negations 
  pos_tokens = word_tokenize(resulting_text)
  probable_negation_positions = []
  original_resulting_text_tokens = pos_tokens.copy()
  for i in range(len(pos_tokens)):
    if str(pos_tokens[i]) in negations:
      probable_negation_positions.append(i)
      probable_negation_positions.append(i+1)
      probable_negation_positions.append(i+2)





  ##### REPLACE NEGATED WORD BY THEIR ANTONYMS
  import nltk
  from nltk.sentiment.util import mark_negation
  nlp = spacy.load("en_core_web_sm")

  text = resulting_text.strip().lower()
  text_tokens = text.split()
  result = []

  # Remove stopwords and punctuations
  for token in text_tokens:
    if token not in stopwords_eng or token in negations:
      result.append(re.sub(r'[^\w\s]','',token))
  clean_result = []
  for item in result:
    if item != '':
      clean_result.append(item)

  final = []
  for item in clean_result:
    if nlp(item)[0].pos_ != "NOUN" or item in negations:
      final.append(item)
  result_text = ' '.join(final)
  # print("result Text is - ", result_text)

  # Tokenize the text into words
  words = nltk.word_tokenize(result_text)
  # Mark the negations in the text
  negation_marked_words = mark_negation(words)
  # Extract the negated words
  negations_NEG=[]
  for item in negations:
    negations_NEG.append(item+'_NEG')
  negated_words = [word for word in negation_marked_words if "_NEG" in word and word not in negations_NEG]

  negated_word_original = []
  for item in negated_words:
    negated_word_original.append(item[:-4])
  # print("Negated words in the text are : ", negated_word_original)

  # Replacing negated words with their antonyms
  # Define a function to get antonyms of a word using WordNet
  # get the closest antonym of a word using WordNet

  toks = list(word_tokenize(resulting_text))

  for i in range(len(toks)):
    if toks[i] in negated_word_original:
      if i in probable_negation_positions:
        toks[i] = get_closest_antonym(toks[i])
  for i in range(len(toks)):
    toks[i] = str(toks[i])  
  antonym_text = ' '.join(toks)
  # aspect_resulting_input = []
  # for i in range(len(toks)):
  #   if toks[i] not in negations:
  #     aspect_resulting_input.append(toks[i])

  # for i in range(len(aspect_resulting_input)):
    

  # # Example usage
  # sentence = "it was not friendly"
  # antonyms = get_antonyms_for_negated_words(sentence)
  # print(antonyms)


  ##### EXTRACT ASPECTS AND THEIR DESCRIPTION
  nlp = spacy.load("en_core_web_sm")
  # doc = nlp(resulting_text)
  doc = nlp(antonym_text)
  # Extract aspects and associated adjectives
  aspects = []
  adjectives = []
  aspect_adj_set = dict()
  for token in doc:
      if token.pos_ == "NOUN":
          for child in token.children:
              if child.dep_ == "amod":
                  aspects.append(token.text)
                  adjectives.append(child.text)
                  aspect_adj_set[token.text] = child.text
      elif token.pos_ == "ADJ":
          for child in token.head.children:
              if child.dep_ == "nsubj":
                  aspects.append(child.text)
                  adjectives.append(token.text)
                  aspect_adj_set[child.text] = token.text
  # Print results
  # print("\n\nAspects:", aspects)
  # print("Adjectives:", adjectives)
  # print("Aspects With Description:", aspect_adj_set)


  import afinn
  # initialize the AFINN lexicon
  afn = afinn.Afinn()

  aspect_sentiment_scores = dict()
  for aspect in aspect_adj_set:
    aspect_sentiment_scores[aspect] = afn.score(aspect_adj_set[aspect].lower())
  # print("Aspects With Sentiment Scores (-5 to +5): ", aspect_sentiment_scores)

  aspect_ratings = dict()
  for aspect in aspect_sentiment_scores:
    if aspect_sentiment_scores[aspect]<0.0:
      if aspect_sentiment_scores[aspect]<=-4.0:
        aspect_ratings[aspect] = 1
      else:
        aspect_ratings[aspect] = 2
    elif aspect_sentiment_scores[aspect]==0.0:
      aspect_ratings[aspect] = 3
    else:
      if aspect_sentiment_scores[aspect]<=3.0:
        aspect_ratings[aspect] = 4
      else:
        aspect_ratings[aspect] = 5
  return aspect_ratings
# Out:
# Requirement already satisfied: afinn in c:\users\shree\anaconda3\lib\site-packages (0.1)
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shree\anaconda3\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
new_df.head(5)
# Out:
#    index                                       product_name  \
# 0      0                    sphere: books: michael crichton
# 1      1  healing from the heart: a leading surgeon comb...
# 2      2  mythology: dc comics art of alex ross 2007 cal...
# 3      4  guns, germs, and steel: the fates of human soc...
# 4      5  world's fairs and the end of progress: an insi...
#
#                                          review_text  rating  \
# 0  sphere michael crichton excellant novel certai...     5.0
# 1  dr oz accomplished heart surgeon field cardiac...     4.0
# 2  gorgeous artwork comic books contains extraord...     5.0
# 3  going short sweet review many others commented...     5.0
# 4  since worlds fair fanatic read almost everythi...     4.0
#
#   initial_sentiment normal_sentiment_score normal_sentiment  \
# 0          positive                 0.9231         positive
# 1          positive                   0.93         positive
# 2          positive                 0.9118         positive
# 3          positive                 0.9912         positive
# 4          positive                 0.9633         positive
#
#   rating_by_normal_sentiment
# 0                          5
# 1                          5
# 2                          5
# 3                          5
# 4                          5

# %%
# select rows for different product categories 
selected_rows = pd.concat([new_df.iloc[0:51], new_df.iloc[7545:7596], new_df.iloc[41760:41811], new_df.iloc[60495:60546]])

# create a new dataframe from the selected rows
sample_df = pd.DataFrame(selected_rows)

# sample_df = new_df.iloc[:10000]
# sample_df

# %%
sample_df
# Out:
#        index                                       product_name  \
# 0          0                    sphere: books: michael crichton
# 1          1  healing from the heart: a leading surgeon comb...
# 2          2  mythology: dc comics art of alex ross 2007 cal...
# 3          4  guns, germs, and steel: the fates of human soc...
# 4          5  world's fairs and the end of progress: an insi...
# ...      ...                                                ...
# 60541  72128  mario batali flexible nylon turner with soft-g...
# 60542  72129  pedrini black & satin gravy separator: kitchen...
# 60543  72130  breville 800cpxl die-cast stainless-steel moto...
# 60544  72132  breville 800cpxl die-cast stainless-steel moto...
# 60545  72133  breville 800cpxl die-cast stainless-steel moto...
#
#                                              review_text  rating  \
# 0      sphere michael crichton excellant novel certai...     5.0
# 1      dr oz accomplished heart surgeon field cardiac...     4.0
# 2      gorgeous artwork comic books contains extraord...     5.0
# 3      going short sweet review many others commented...     5.0
# 4      since worlds fair fanatic read almost everythi...     4.0
# ...                                                  ...     ...
# 60541  sort spatula addiction far many spatulas alway...     4.0
# 60542  real test see works separate fat broth liquids...     5.0
# 60543  purchased machine 3 months ago necessity prima...     5.0
# 60544  looking citrus juicer quite while orange grape...     5.0
# 60545  outstanding citrus press powerful gets job don...     5.0
#
#       initial_sentiment normal_sentiment_score normal_sentiment  \
# 0              positive                 0.9231         positive
# 1              positive                   0.93         positive
# 2              positive                 0.9118         positive
# 3              positive                 0.9912         positive
# 4              positive                 0.9633         positive
# ...                 ...                    ...              ...
# 60541          positive                 0.9764         positive
# 60542          positive                 0.8442         positive
# 60543          positive                 0.8896         positive
# 60544          positive                 0.6362         positive
# 60545          positive                 0.9359         positive
#
#       rating_by_normal_sentiment
# 0                              5
# 1                              5
# 2                              5
# 3                              5
# 4                              5
# ...                          ...
# 60541                          5
# 60542                          5
# 60543                          5
# 60544                          5
# 60545                          5
#
# [204 rows x 8 columns]

# %%
sample_df['aspect_ratings'] = sample_df['review_text'].apply(retrieve_aspects_and_sentiments)

# %%
sample_df
# Out:
#        index                                       product_name  \
# 0          0                    sphere: books: michael crichton
# 1          1  healing from the heart: a leading surgeon comb...
# 2          2  mythology: dc comics art of alex ross 2007 cal...
# 3          4  guns, germs, and steel: the fates of human soc...
# 4          5  world's fairs and the end of progress: an insi...
# ...      ...                                                ...
# 60541  72128  mario batali flexible nylon turner with soft-g...
# 60542  72129  pedrini black & satin gravy separator: kitchen...
# 60543  72130  breville 800cpxl die-cast stainless-steel moto...
# 60544  72132  breville 800cpxl die-cast stainless-steel moto...
# 60545  72133  breville 800cpxl die-cast stainless-steel moto...
#
#                                              review_text  rating  \
# 0      sphere michael crichton excellant novel certai...     5.0
# 1      dr oz accomplished heart surgeon field cardiac...     4.0
# 2      gorgeous artwork comic books contains extraord...     5.0
# 3      going short sweet review many others commented...     5.0
# 4      since worlds fair fanatic read almost everythi...     4.0
# ...                                                  ...     ...
# 60541  sort spatula addiction far many spatulas alway...     4.0
# 60542  real test see works separate fat broth liquids...     5.0
# 60543  purchased machine 3 months ago necessity prima...     5.0
# 60544  looking citrus juicer quite while orange grape...     5.0
# 60545  outstanding citrus press powerful gets job don...     5.0
#
#       initial_sentiment normal_sentiment_score normal_sentiment  \
# 0              positive                 0.9231         positive
# 1              positive                   0.93         positive
# 2              positive                 0.9118         positive
# 3              positive                 0.9912         positive
# 4              positive                 0.9633         positive
# ...                 ...                    ...              ...
# 60541          positive                 0.9764         positive
# 60542          positive                 0.8442         positive
# 60543          positive                 0.8896         positive
# 60544          positive                 0.6362         positive
# 60545          positive                 0.9359         positive
#
#       rating_by_normal_sentiment  \
# 0                              5
# 1                              5
# 2                              5
# 3                              5
# 4                              5
# ...                          ...
# 60541                          5
# 60542                          5
# 60543                          5
# 60544                          5
# 60545                          5
#
#                                           aspect_ratings
# 0      {'novel': 3, 'misssion': 3, 'mile': 3, 'spacec...
# 1      {'transplantation': 4, 'epilogue': 4, 'medicin...
# 2                             {'books': 4, 'artwork': 3}
# 3      {'review': 4, 'others': 2, 'value': 3, 'though...
# 4      {'worlds': 4, 'read': 4, 'book_author': 3, 'er...
# ...                                                  ...
# 60541  {'spatulas': 4, 'spatula': 4, 'turn': 3, 'food...
# 60542  {'test': 3, 'refrigerate': 3, 'saves': 3, 'eat...
# 60543  {'months_necessity': 3, 'reviews': 4, 'machine...
# 60544                                         {'use': 4}
# 60545  {'citrus_press': 4, 'use': 4, 'party': 4, 'sta...
#
# [204 rows x 9 columns]

# %%
# Saving the intermediate dataframe for further reference
sample_df.to_excel(r"C:\Users\shree\OneDrive\Desktop\IIITD Sem 2\I R\updated_baseline_results.xlsx")

# %%
sample_df.head(5)
# Out:
#    index                                       product_name  \
# 0      0                    sphere: books: michael crichton
# 1      1  healing from the heart: a leading surgeon comb...
# 2      2  mythology: dc comics art of alex ross 2007 cal...
# 3      4  guns, germs, and steel: the fates of human soc...
# 4      5  world's fairs and the end of progress: an insi...
#
#                                          review_text  rating  \
# 0  sphere michael crichton excellant novel certai...     5.0
# 1  dr oz accomplished heart surgeon field cardiac...     4.0
# 2  gorgeous artwork comic books contains extraord...     5.0
# 3  going short sweet review many others commented...     5.0
# 4  since worlds fair fanatic read almost everythi...     4.0
#
#   initial_sentiment normal_sentiment_score normal_sentiment  \
# 0          positive                 0.9231         positive
# 1          positive                   0.93         positive
# 2          positive                 0.9118         positive
# 3          positive                 0.9912         positive
# 4          positive                 0.9633         positive
#
#   rating_by_normal_sentiment  \
# 0                          5
# 1                          5
# 2                          5
# 3                          5
# 4                          5
#
#                                       aspect_ratings
# 0  {'novel': 3, 'misssion': 3, 'mile': 3, 'spacec...
# 1  {'transplantation': 4, 'epilogue': 4, 'medicin...
# 2                         {'books': 4, 'artwork': 3}
# 3  {'review': 4, 'others': 2, 'value': 3, 'though...
# 4  {'worlds': 4, 'read': 4, 'book_author': 3, 'er...

# %% [markdown]
# ## Accuracy with Compound Sentiment Score

# %%
# Calculating accuracy for our rating 
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# Define the true labels and predicted labels
user_rating = list(sample_df['rating'])
our_rating = list(sample_df['rating_by_normal_sentiment'])
true_labels = user_rating
predicted_labels = our_rating

# Generate the confusion matrix
cm_normal = confusion_matrix(true_labels, predicted_labels)

# Generate the classification report
cr_normal = classification_report(true_labels, predicted_labels)

# Print the confusion matrix and classification report
# Plotting heatmap
import seaborn as sns
fig, ax = plt.subplots(figsize=(15,8)) 
sns.heatmap(cm_normal, annot=True, ax=ax)

ax.set_title('Heatmap for Caculated Rating Vs Original Rating', fontdict = {'fontsize' : 20})
plt.show()
print("\nClassification report:\n", cr_normal)
# Accuracy of initial sentiment calculated by rating given Vs compound sentiment score calculated by SentimentIntensityAnalyzer()
from sklearn.metrics import accuracy_score
print("Calculated Sentiment Accuracy ",accuracy_score(sample_df['initial_sentiment'], sample_df['normal_sentiment']))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#          1.0       1.00      0.38      0.55         8
#          2.0       0.20      0.75      0.32         4
#          3.0       0.00      0.00      0.00         0
#          4.0       0.22      0.04      0.06        56
#          5.0       0.74      0.95      0.83       136
#
#     accuracy                           0.67       204
#    macro avg       0.43      0.42      0.35       204
# weighted avg       0.60      0.67      0.60       204
#
# Calculated Sentiment Accuracy  0.9411764705882353
